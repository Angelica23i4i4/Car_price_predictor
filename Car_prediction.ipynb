# %%
import pandas as pd
import numpy as np
import random


# из sklearn мы импортируем алгоритм k-ближайших соседей
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df = pd.read_csv('/content/used_cars.csv')
df
# Out:
#          brand                            model  model_year      milage  \
# 0         Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1      Hyundai                     Palisade SEL        2021  34,742 mi.
# 2        Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3     INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4         Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
# ...        ...                              ...         ...         ...
# 4004   Bentley             Continental GT Speed        2023     714 mi.
# 4005      Audi             S4 3.0T Premium Plus        2022  10,900 mi.
# 4006   Porsche                           Taycan        2022   2,116 mi.
# 4007      Ford                     F-150 Raptor        2020  33,000 mi.
# 4008       BMW                     X3 xDrive30i        2020  43,000 mi.
#
#           fuel_type                                             engine  \
# ...

# %%
df = df.drop(columns=['engine', 'int_col', 'fuel_type', 'model', 'ext_col', 'clean_title'], axis=1)

# %%
df
# Out:
#          brand  model_year      milage                       transmission  \
# 0         Ford        2013  51,000 mi.                        6-Speed A/T
# 1      Hyundai        2021  34,742 mi.                  8-Speed Automatic
# 2        Lexus        2022  22,372 mi.                          Automatic
# 3     INFINITI        2015  88,900 mi.                        7-Speed A/T
# 4         Audi        2021   9,835 mi.                  8-Speed Automatic
# ...        ...         ...         ...                                ...
# 4004   Bentley        2023     714 mi.  8-Speed Automatic with Auto-Shift
# 4005      Audi        2022  10,900 mi.     Transmission w/Dual Shift Mode
# 4006   Porsche        2022   2,116 mi.                          Automatic
# 4007      Ford        2020  33,000 mi.                                A/T
# 4008       BMW        2020  43,000 mi.                                A/T
#
#                                     accident     price
# ...

# %%
x = df.drop('price', axis=1)
y = df['price']

# %%
y = y.apply(lambda x: int(x.replace('$', '').replace(',','')))

# %%
! pip install category_encoders

# %%
from category_encoders.target_encoder import TargetEncoder
from category_encoders.one_hot import OneHotEncoder
from category_encoders.ordinal import OrdinalEncoder

encoder = TargetEncoder(cols=['brand', 'transmission'], smoothing=1)
encoder1 = OneHotEncoder()
encoder2 = OrdinalEncoder()

# %%
x['milage'] = x['milage'].apply(lambda x: int(x.replace(' mi.', '').replace(',','')))

# %%
x
# Out:
#          brand  model_year  milage                       transmission  \
# 0         Ford        2013   51000                        6-Speed A/T
# 1      Hyundai        2021   34742                  8-Speed Automatic
# 2        Lexus        2022   22372                          Automatic
# 3     INFINITI        2015   88900                        7-Speed A/T
# 4         Audi        2021    9835                  8-Speed Automatic
# ...        ...         ...     ...                                ...
# 4004   Bentley        2023     714  8-Speed Automatic with Auto-Shift
# 4005      Audi        2022   10900     Transmission w/Dual Shift Mode
# 4006   Porsche        2022    2116                          Automatic
# 4007      Ford        2020   33000                                A/T
# 4008       BMW        2020   43000                                A/T
#
#                                     accident
# 0     At least 1 accident or damage reported
# ...

# %%
accident = encoder1.fit_transform(x['accident'])

# %%
#milage = encoder2.fit_transform(x['milage'])

# %%
x['model_year'] = x['model_year'].astype(str)
year = encoder2.fit_transform(x['model_year'])

# %%
x = x.drop('milage', axis=1)
x.insert(loc=2,column='milage', value=milage)

# %%
x = x.drop('model_year', axis=1)
x.insert(loc=1,column='model_year', value=year)

# %%
x1 = x.drop('accident', axis=1)
x = pd.concat([x1, accident], axis='columns', join='outer')
x
# Out:
#          brand  model_year  milage                       transmission  \
# 0         Ford           1   51000                        6-Speed A/T
# 1      Hyundai           2   34742                  8-Speed Automatic
# 2        Lexus           3   22372                          Automatic
# 3     INFINITI           4   88900                        7-Speed A/T
# 4         Audi           2    9835                  8-Speed Automatic
# ...        ...         ...     ...                                ...
# 4004   Bentley          12     714  8-Speed Automatic with Auto-Shift
# 4005      Audi           3   10900     Transmission w/Dual Shift Mode
# 4006   Porsche           3    2116                          Automatic
# 4007      Ford           8   33000                                A/T
# 4008       BMW           8   43000                                A/T
#
#       accident_1  accident_2  accident_3
# 0              1           0           0
# 1              1           0           0
# ...

# %%
x = x.drop(['accident_2', 'accident_3'], axis=1)
x
# Out:
#          brand  model_year  milage                       transmission  \
# 0         Ford           1   51000                        6-Speed A/T
# 1      Hyundai           2   34742                  8-Speed Automatic
# 2        Lexus           3   22372                          Automatic
# 3     INFINITI           4   88900                        7-Speed A/T
# 4         Audi           2    9835                  8-Speed Automatic
# ...        ...         ...     ...                                ...
# 4004   Bentley          12     714  8-Speed Automatic with Auto-Shift
# 4005      Audi           3   10900     Transmission w/Dual Shift Mode
# 4006   Porsche           3    2116                          Automatic
# 4007      Ford           8   33000                                A/T
# 4008       BMW           8   43000                                A/T
#
#       accident_1
# 0              1
# 1              1
# 2              0
# 3              0
# 4              0
# ...

# %%
x = encoder.fit_transform(x,y)
x
# Out:
#               brand  model_year  milage  transmission  accident_1
# 0      36240.880829           1   51000  25450.044199           1
# 1      18946.875000           2   34742  66071.812500           1
# 2      35668.521472           3   22372  63105.021097           0
# 3      22927.644068           4   88900  47249.669856           0
# 4      39907.430000           2    9835  66071.812500           0
# ...             ...         ...     ...           ...         ...
# 4004  137553.335244          12     714  44555.504711           0
# 4005   39907.430000           3   10900  54710.615578           0
# 4006   88751.298507           3    2116  63105.021097           0
# 4007   36240.880829           8   33000  31507.603664           0
# 4008   41072.309333           8   43000  31507.603664           1
#
# [4009 rows x 5 columns]

# %%
df = pd.concat([x,y],axis='columns', join='outer')
df
# Out:
#               brand  model_year  milage  transmission  accident_1   price
# 0      36240.880829           1   51000  25450.044199           1   10300
# 1      18946.875000           2   34742  66071.812500           1   38005
# 2      35668.521472           3   22372  63105.021097           0   54598
# 3      22927.644068           4   88900  47249.669856           0   15500
# 4      39907.430000           2    9835  66071.812500           0   34999
# ...             ...         ...     ...           ...         ...     ...
# 4004  137553.335244          12     714  44555.504711           0  349950
# 4005   39907.430000           3   10900  54710.615578           0   53900
# 4006   88751.298507           3    2116  63105.021097           0   90998
# 4007   36240.880829           8   33000  31507.603664           0   62999
# 4008   41072.309333           8   43000  31507.603664           1   40000
#
# [4009 rows x 6 columns]

# %%
scaler = StandardScaler()
df_new = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
df2 = df.join(df_new, rsuffix='_right', how='outer').reset_index(drop=True)
df2
# Out:
#               brand  model_year  milage  transmission  accident_1   price  \
# 0      36240.880829           1   51000  25450.044199           1   10300
# 1      18946.875000           2   34742  66071.812500           1   38005
# 2      35668.521472           3   22372  63105.021097           0   54598
# 3      22927.644068           4   88900  47249.669856           0   15500
# 4      39907.430000           2    9835  66071.812500           0   34999
# ...             ...         ...     ...           ...         ...     ...
# 4004  137553.335244          12     714  44555.504711           0  349950
# 4005   39907.430000           3   10900  54710.615578           0   53900
# 4006   88751.298507           3    2116  63105.021097           0   90998
# 4007   36240.880829           8   33000  31507.603664           0   62999
# 4008   41072.309333           8   43000  31507.603664           1   40000
#
#       brand_right  model_year_right  milage_right  transmission_right  \
# ...

# %%
year_new = df2.loc[df2['model_year'] == 2021, 'model_year_right']
year_new
# Out:
# 1      -1.160593
# 4      -1.160593
# 8      -1.160593
# 10     -1.160593
# 12     -1.160593
#           ...
# 3961   -1.160593
# 3962   -1.160593
# 3971   -1.160593
# 3993   -1.160593
# 4000   -1.160593
# Name: model_year_right, Length: 350, dtype: float64

# %%
x = df_new.drop('price', axis=1)
y = df_new['price']

# %%
x_train, x_test, y_train, y_test =  train_test_split(x, y, test_size=0.25, random_state=125)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
pred = model.predict(x_test)

# %%
MSE = mean_squared_error(pred, y_test)
MSE
# Out:
# 0.17484910673472848

# %%
x_train
# Out:
#          brand  model_year    milage  transmission  accident_1
# 896  -0.503962   -1.160593 -0.478256      1.054662   -0.571109
# 1580 -0.443307    1.474403  0.119659     -0.526741   -0.571109
# 1881 -0.443307    0.156905 -1.386650      0.070129   -0.571109
# 3910 -0.443307   -1.160593  0.079637     -0.526741   -0.571109
# 3246  0.477658   -1.306982 -0.183543     -0.803890    1.750978
# ...        ...         ...       ...           ...         ...
# 1122  0.345683    1.767180 -0.264801      0.193500   -0.571109
# 1346 -0.571482   -1.014204 -0.068326      0.370842   -0.571109
# 3454 -0.089728   -1.160593  1.585946     -0.526741   -0.571109
# 3437  1.658015    1.767180  1.567754      0.534857   -0.571109
# 3582  0.477658   -0.282261 -0.907590     -0.526741   -0.571109
#
# [3006 rows x 5 columns]

# %%
df_new2 = df_new.sample(40)
x_new = df_new2.drop('price', axis=1)
y_new = df_new2['price']

# %%
x_train, x_test, y_train, y_test =  train_test_split(x_new, y_new, test_size=0.25, random_state=125)

# %%
model.fit(x_train, y_train)
pred = model.predict(x_test)

# %%
MSE = mean_squared_error(pred, y_test)
MSE
# Out:
# 0.10198221273335799
